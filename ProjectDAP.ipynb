# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Supriya Nanekar\Downloads\cleaned.csv")
df
# Out:
#        item_id  user_id  rating  timestamp  gender    category       brand  \
# 0            7      131       4      36692  Female  Home Audio     Philips
# 1           19      231       5      36891  Female      Camera       Canon
# 2           14      233       5      36893  Female      Camera       Kodak
# 3           14      257       5      36926  Female      Camera       Kodak
# 4           14      269       5      36952  Female      Camera       Kodak
# ...        ...      ...     ...        ...     ...         ...         ...
# 45161     7828  1157458       5      43341  Female  Headphones        Bose
# 45162     8624  1157504       5      43342  Female  Headphones        Pyle
# 45163     9513  1157527       5      43344    Male  Headphones        Mpow
# 45164     9125  1157555       3      43348  Female  Headphones      EldHus
# 45165     9478  1157632       1      43374  Female  Headphones  Etre Jeune
#
#        year  month  quantity  unitprice  amount
# ...

# %%
df.head()
# Out:
#    item_id  user_id  rating  timestamp  gender    category    brand  year  \
# 0        7      131       4      36692  Female  Home Audio  Philips  2000
# 1       19      231       5      36891  Female      Camera    Canon  2000
# 2       14      233       5      36893  Female      Camera    Kodak  2001
# 3       14      257       5      36926  Female      Camera    Kodak  2001
# 4       14      269       5      36952  Female      Camera    Kodak  2001
#
#    month  quantity  unitprice  amount
# 0      6         5       6360   31800
# 1     12        10       9955   99550
# 2      1         9       7639   68751
# 3      2         7       5097   35679
# 4      3        10       6472   64720

# %%
df.shape
# Out:
# (45166, 12)

# %%
df.tail()
# Out:
#        item_id  user_id  rating  timestamp  gender    category       brand  \
# 45161     7828  1157458       5      43341  Female  Headphones        Bose
# 45162     8624  1157504       5      43342  Female  Headphones        Pyle
# 45163     9513  1157527       5      43344    Male  Headphones        Mpow
# 45164     9125  1157555       3      43348  Female  Headphones      EldHus
# 45165     9478  1157632       1      43374  Female  Headphones  Etre Jeune
#
#        year  month  quantity  unitprice  amount
# 45161  2018      8         9       5925   41475
# 45162  2018      8         9       9717   68019
# 45163  2018      9        10       9197   73576
# 45164  2018      9        12       8848   88480
# 45165  2018     10         9       7717   54019

# %%
df.isnull().sum()
# Out:
# item_id      0
# user_id      0
# rating       0
# timestamp    0
# gender       0
# category     0
# brand        0
# year         0
# month        0
# quantity     0
# unitprice    0
# amount       0
# dtype: int64

# %%
df['category'].value_counts()
# Out:
# category
# Headphones                 16211
# Computers & Accessories    10108
# Camera                      9153
# Portable Audio & Video      3351
# Accessories & Supplies      2414
# Home Audio                  1392
# Television & Video          1222
# Car Electronics & GPS       1094
# Security & Surveillance      134
# Wearable Technology           87
# Name: count, dtype: int64

# %%
df['brand'].value_counts()
# Out:
# brand
# Logitech        4344
# Bose            4336
# Sony            2979
# EldHus          2469
# Mpow            2259
# Fujifilm        1860
# TaoTronics      1736
# Sennheiser      1687
# Etre Jeune      1565
# Panasonic       1420
# JLAB            1418
# Pyle            1339
# Skullcandy      1310
# Samsung         1119
# Fintie          1005
# Kodak            971
# Philips          928
# Jabra            909
# Polaroid         874
# Nikon            841
# Apple            832
# Canon            831
# Neewer           790
# Linksys          750
# Garmin           684
# Uniden           576
# DBPOWER          571
# ViewSonic        558
# Olympus          470
# LSS              447
# ebasy            346
# Plemo            329
# Savage           284
# HP               262
# Toshiba          255
# XShields         239
# Tiamat           217
# Generic          211
# Gary Fong        174
# JVC              160
# iRULU            114
# Kensington       112
# Vivitar          104
# ...

# %%
df[df['rating'].isin([4,5])]
# Out:
#        item_id  user_id  rating  timestamp  gender                 category  \
# 0            7      131       4      36692  Female               Home Audio
# 1           19      231       5      36891  Female                   Camera
# 2           14      233       5      36893  Female                   Camera
# 3           14      257       5      36926  Female                   Camera
# 4           14      269       5      36952  Female                   Camera
# ...        ...      ...     ...        ...     ...                      ...
# 45158     7869  1157373       4      43339  Female               Headphones
# 45159     8655  1157392       5      43340  Female  Computers & Accessories
# 45161     7828  1157458       5      43341  Female               Headphones
# 45162     8624  1157504       5      43342  Female               Headphones
# 45163     9513  1157527       5      43344    Male               Headphones
#
# ...

# %%
#removing the given entry eg rating =1
df[~(df['rating']<=1)]
# Out:
#        item_id  user_id  rating  timestamp  gender    category    brand  year  \
# 0            7      131       4      36692  Female  Home Audio  Philips  2000
# 1           19      231       5      36891  Female      Camera    Canon  2000
# 2           14      233       5      36893  Female      Camera    Kodak  2001
# 3           14      257       5      36926  Female      Camera    Kodak  2001
# 4           14      269       5      36952  Female      Camera    Kodak  2001
# ...        ...      ...     ...        ...     ...         ...      ...   ...
# 45160     8863   728481       2      43340  Female  Headphones   Tiamat  2018
# 45161     7828  1157458       5      43341  Female  Headphones     Bose  2018
# 45162     8624  1157504       5      43342  Female  Headphones     Pyle  2018
# 45163     9513  1157527       5      43344    Male  Headphones     Mpow  2018
# 45164     9125  1157555       3      43348  Female  Headphones   EldHus  2018
#
# ...

# %%
df.shape
# Out:
# (45166, 12)

# %%
#for increasing the value of quantity
df['quantity']=df['quantity'].apply(lambda x:x+2)

# %%
df
# Out:
#        item_id  user_id  rating  timestamp  gender    category       brand  \
# 0            7      131       4      36692  Female  Home Audio     Philips
# 1           19      231       5      36891  Female      Camera       Canon
# 2           14      233       5      36893  Female      Camera       Kodak
# 3           14      257       5      36926  Female      Camera       Kodak
# 4           14      269       5      36952  Female      Camera       Kodak
# ...        ...      ...     ...        ...     ...         ...         ...
# 45161     7828  1157458       5      43341  Female  Headphones        Bose
# 45162     8624  1157504       5      43342  Female  Headphones        Pyle
# 45163     9513  1157527       5      43344    Male  Headphones        Mpow
# 45164     9125  1157555       3      43348  Female  Headphones      EldHus
# 45165     9478  1157632       1      43374  Female  Headphones  Etre Jeune
#
#        year  month  quantity  unitprice  amount
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
monthly_sales = df.groupby('month')['amount'].sum()
plt.plot(monthly_sales.index, monthly_sales.values, marker='o', linestyle='-', color='b')
plt.title("Total Sales Over Time")
plt.xlabel("Year-Month")
plt.ylabel("Total Sales Amount")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
top_categories = df.groupby("category")["amount"].sum().sort_values(ascending=False).head(10)
plt.bar(top_categories.index, top_categories.values, color='skyblue')
plt.title("Top 10 Best-Selling Product Categories")
plt.xlabel("Category")
plt.ylabel("Total Sales Amount")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(7, 7))
gender_sales = df.groupby("gender")["amount"].sum()
plt.pie(gender_sales, labels=gender_sales.index, autopct='%1.1f%%', colors=['#FF9999', '#66B3FF'], startangle=140)
plt.title("Sales Distribution by Gender")
plt.show()

# %%
plt.figure(figsize=(12, 6))
top_brands = df.groupby("brand")["amount"].sum().sort_values(ascending=False).head(10)
plt.bar(top_brands.index, top_brands.values, color='green')
plt.title("Top 10 Best-Selling Brands")
plt.xlabel("Brand")
plt.ylabel("Total Sales Amount")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(df["rating"], bins=5, color='purple', edgecolor='black', alpha=0.7)
plt.title("Rating Distribution")
plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
